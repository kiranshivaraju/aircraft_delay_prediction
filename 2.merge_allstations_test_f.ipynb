# %%
import pandas as pd

# %%
test=pd.read_csv('C:/Users/kiran/OneDrive/Desktop/hacakthon_final/ProblemStatement_Data&Instructions-1616503373207/DataForPHD_Forall/20210328_Testdata/Test.csv')

# %%
test
# Out:
#         FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0      DEN_XNA_62349  2005      9          12          1              1516
# 1      RIC_EWR_87213  2005     11          14          1              1300
# 2      IAD_GSO_86576  2005      9          28          3              1040
# 3      SAV_CVG_87264  2005     11          18          5              1120
# 4      SBP_LAX_68158  2005      7           5          2               630
# ...              ...   ...    ...         ...        ...               ...
# 6561   LAX_EWR_82392  2005     11          21          1              1210
# 6562   ORD_BOS_71467  2005     11          25          5              1717
# 6563  MCI_BWI_101601  2005      3          26          6              1210
# 6564   SLC_COD_68517  2005      9          21          3              1550
# 6565   MCI_ABQ_65005  2005      7          19          2              1135
#
# ...

# %%
allstationsdf=pd.read_csv('C:/Users/kiran/OneDrive/Desktop/hacakthon_final/ProblemStatement_Data&Instructions-1616503373207/DataForPHD_Forall/20210322_weatherdatatoconsider/AllStationsData_PHD.txt', delimiter='|')

# %%
allstationsdf
# Out:
#       WeatherStationID AirportID  GroundHeight  StationHeight  \
# 0                 3011       TEX             0              0
# 1                 3012       SKX             0              0
# 2                 3013       LAA          3683           3703
# 3                 3014       4SL             0           6909
# 4                 3016       RIL          5503           5544
# ...                ...       ...           ...            ...
# 1739             94997       ADC             0              0
# 1740             94998       ADU             0              0
# 1741             94999       AIT             0           1204
# 1742             96401       IEC             0           1350
# 1743             96402       JVM             0            870
#
#       BarometerHeight  Latitude  Longitude TimeZone
# 0                   0     37.57    -107.55       +7
# 1                   0     36.28    -105.40       +7
# 2                3675     38.04    -102.41       +7
# ...

# %%
origin_df=pd.merge(test, allstationsdf, left_on='Origin', right_on='AirportID')

# %%
origin_df.head()
# Out:
#     FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  DEN_XNA_62349  2005      9          12          1              1516
# 1  DEN_SAT_82515  2005      9           6          2               855
# 2  DEN_ICT_94174  2005      7          23          6              1556
# 3  DEN_SAT_78504  2005      9           4          7              1230
# 4  DEN_PHL_82820  2005      3          23          3              1405
#
#    ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0              1756                  100    DEN         XNA       616
# 1              1157                  122    DEN         SAT       794
# 2              1817                   81    DEN         ICT       419
# 3              1529                  119    DEN         SAT       794
# 4              1925                  200    DEN         PHL      1557
#
#    WeatherStationID AirportID  GroundHeight  StationHeight  BarometerHeight  \
# ...

# %%
origin_df
# Out:
#        FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0     DEN_XNA_62349  2005      9          12          1              1516
# 1     DEN_SAT_82515  2005      9           6          2               855
# 2     DEN_ICT_94174  2005      7          23          6              1556
# 3     DEN_SAT_78504  2005      9           4          7              1230
# 4     DEN_PHL_82820  2005      3          23          3              1405
# ...             ...   ...    ...         ...        ...               ...
# 6561  GTR_ATL_83479  2005      3          20          7              1415
# 6562  BRO_IAH_75040  2005      3           7          1              1330
# 6563  BRO_IAH_98355  2005      3          16          3              1330
# 6564  FSM_DFW_89528  2005      3           7          1               750
# 6565  CMI_DFW_66446  2005      7          24          7               739
#
#       ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# ...

# %%
dest_df=pd.merge(test, allstationsdf, left_on='Destination', right_on='AirportID')

# %%
dest_df.head()
# Out:
#     FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  DEN_XNA_62349  2005      9          12          1              1516
# 1  ORD_XNA_65795  2005      9          30          5               800
# 2  ORD_XNA_98655  2005     11          11          5               800
# 3  DFW_XNA_75074  2005     11           8          2              1219
# 4  ATL_XNA_81150  2005      3           1          2               708
#
#    ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0              1756                  100    DEN         XNA       616
# 1               948                  108    ORD         XNA       522
# 2               947                  107    ORD         XNA       522
# 3              1327                   68    DFW         XNA       281
# 4               758                  110    ATL         XNA       589
#
#    WeatherStationID AirportID  GroundHeight  StationHeight  BarometerHeight  \
# ...

# %%
dest_df
# Out:
#        FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0     DEN_XNA_62349  2005      9          12          1              1516
# 1     ORD_XNA_65795  2005      9          30          5               800
# 2     ORD_XNA_98655  2005     11          11          5               800
# 3     DFW_XNA_75074  2005     11           8          2              1219
# 4     ATL_XNA_81150  2005      3           1          2               708
# ...             ...   ...    ...         ...        ...               ...
# 6561  CVG_ACY_87937  2005      3          18          5              1140
# 6562  DEN_BIL_99332  2005      9          29          4              1425
# 6563  SLC_COD_96091  2005      9          17          6              1550
# 6564  SLC_COD_68517  2005      9          21          3              1550
# 6565  ANC_SCC_62899  2005      3           8          2              1137
#
#       ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# ...

# %%
merged=pd.merge(origin_df,dest_df, on='FlightNumber',how='inner')

# %%
merged
# Out:
#        FlightNumber  Year_x  Month_x  DayofMonth_x  DayOfWeek_x  \
# 0     DEN_XNA_62349    2005        9            12            1
# 1     DEN_SAT_82515    2005        9             6            2
# 2     DEN_ICT_94174    2005        7            23            6
# 3     DEN_SAT_78504    2005        9             4            7
# 4     DEN_PHL_82820    2005        3            23            3
# ...             ...     ...      ...           ...          ...
# 6561  GTR_ATL_83479    2005        3            20            7
# 6562  BRO_IAH_75040    2005        3             7            1
# 6563  BRO_IAH_98355    2005        3            16            3
# 6564  FSM_DFW_89528    2005        3             7            1
# 6565  CMI_DFW_66446    2005        7            24            7
#
#       ScheduledDepTime_x  ScheduledArrTime_x  ScheduledTravelTime_x Origin_x  \
# 0                   1516                1756                    100      DEN
# ...

# %%
merged.columns
# Out:
# Index(['FlightNumber', 'Year_x', 'Month_x', 'DayofMonth_x', 'DayOfWeek_x',
#        'ScheduledDepTime_x', 'ScheduledArrTime_x', 'ScheduledTravelTime_x',
#        'Origin_x', 'Destination_x', 'Distance_x', 'WeatherStationID_x',
#        'AirportID_x', 'GroundHeight_x', 'StationHeight_x', 'BarometerHeight_x',
#        'Latitude_x', 'Longitude_x', 'TimeZone_x', 'Year_y', 'Month_y',
#        'DayofMonth_y', 'DayOfWeek_y', 'ScheduledDepTime_y',
#        'ScheduledArrTime_y', 'ScheduledTravelTime_y', 'Origin_y',
#        'Destination_y', 'Distance_y', 'WeatherStationID_y', 'AirportID_y',
#        'GroundHeight_y', 'StationHeight_y', 'BarometerHeight_y', 'Latitude_y',
#        'Longitude_y', 'TimeZone_y'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['FlightNumber', 'Year', 'Month', 'DayofMonth', 'DayOfWeek',
#        'ScheduledDepTime', 'ScheduledArrTime', 'ScheduledTravelTime', 'Origin',
#        'Destination', 'Distance'],
#       dtype='object')

# %%
merged=merged.drop(['Year_y', 'Month_y', 'DayofMonth_y', 'DayOfWeek_y',
       'ScheduledDepTime_y', 'ScheduledArrTime_y', 'ScheduledTravelTime_y',
       'Origin_y', 'Destination_y', 'Distance_y'],axis=1)

# %%
merged.columns
# Out:
# Index(['FlightNumber', 'Year_x', 'Month_x', 'DayofMonth_x', 'DayOfWeek_x',
#        'ScheduledDepTime_x', 'ScheduledArrTime_x', 'ScheduledTravelTime_x',
#        'Origin_x', 'Destination_x', 'Distance_x', 'WeatherStationID_x',
#        'AirportID_x', 'GroundHeight_x', 'StationHeight_x', 'BarometerHeight_x',
#        'Latitude_x', 'Longitude_x', 'TimeZone_x', 'WeatherStationID_y',
#        'AirportID_y', 'GroundHeight_y', 'StationHeight_y', 'BarometerHeight_y',
#        'Latitude_y', 'Longitude_y', 'TimeZone_y'],
#       dtype='object')

# %%
merged.columns=['FlightNumber', 'Year', 'Month', 'DayofMonth', 'DayOfWeek',
       'ScheduledDepTime', 'ScheduledArrTime', 'ScheduledTravelTime',
       'Origin', 'Destination', 'Distance', 'WeatherStationID_origin',
       'AirportID_origin', 'GroundHeight_origin', 'StationHeight_origin', 'BarometerHeight_origin',
       'Latitude_origin', 'Longitude_origin', 'TimeZone_origin', 'WeatherStationID_dest',
       'AirportID_dest', 'GroundHeight_dest', 'StationHeight_dest', 'BarometerHeight_dest',
       'Latitude_dest', 'Longitude_dest', 'TimeZone_dest']

# %%
merged
# Out:
#        FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0     DEN_XNA_62349  2005      9          12          1              1516
# 1     DEN_SAT_82515  2005      9           6          2               855
# 2     DEN_ICT_94174  2005      7          23          6              1556
# 3     DEN_SAT_78504  2005      9           4          7              1230
# 4     DEN_PHL_82820  2005      3          23          3              1405
# ...             ...   ...    ...         ...        ...               ...
# 6561  GTR_ATL_83479  2005      3          20          7              1415
# 6562  BRO_IAH_75040  2005      3           7          1              1330
# 6563  BRO_IAH_98355  2005      3          16          3              1330
# 6564  FSM_DFW_89528  2005      3           7          1               750
# 6565  CMI_DFW_66446  2005      7          24          7               739
#
#       ScheduledArrTime  ScheduledTravelTime Origin Destination  ...  \
# ...

# %%
merged.shape
# Out:
# (6566, 27)

# %%
merged.to_csv('merged_with_target_allstations_test.csv')
